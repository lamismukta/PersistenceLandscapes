# %%
import numpy as np

# %%
import sys
sys.path.append('../functions')
from barcodes import import_and_plot, ripser_plot

# %% [markdown]
# Barcode for a random point cloud

# %%
random_data = np.random.random((100,2))
ripser_plot(random_data, "Random Points")
# Out:
# Rips(maxdim=2, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %% [markdown]
# Plot ripser persistence diagram from any PDBID, Chain pair

# %%
import_and_plot('1fqm','A')
# Out:
# Rips(maxdim=2, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)
